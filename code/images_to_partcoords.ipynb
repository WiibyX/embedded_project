# %%
from partCoordsOfImage import partCoordsOfImage

from os import listdir
from os.path import isfile, join
import cv2
import pylab as plt

# %%
CImagesDir = r'C:\Users\WillyB\Documents\GitHub\embedded_project\Stanford40_JPEGImages\CImages'
CImagesDir = r'C:\Users\Viktor\Skola\embedded\embedded_project\Stanford40_JPEGImages\CImages'

JPGFiles = [f for f in listdir(CImagesDir) if isfile(join(CImagesDir, f))]
#save JPGFiles Order to txt file
textfile = open("JPG_Order.txt", "w")
for element in JPGFiles:
    textfile.write(element + "\n")
textfile.close()
print("JPG_Oder.txt Done")

test_image = CImagesDir +'/applauding_001.jpg'
oriImg = cv2.imread(test_image) # B,G,R order
plt.imshow(oriImg[:,:,[2,1,0]])
# Out:
# JPG_Oder.txt Done

# %%
partCoordsOfImage(test_image)
# Out:
# array([[125.,  51.],
#        [101., 123.],
#        [ 37., 136.],
#        [ 23., 239.],
#        [ 90., 165.],
#        [164., 108.],
#        [210., 209.],
#        [153., 146.],
#        [ 76., 281.],
#        [ 67., 323.],
#        [ nan,  nan],
#        [161., 283.],
#        [ nan,  nan],
#        [ nan,  nan],
#        [107.,  42.],
#        [126.,  38.],
#        [ 71.,  61.],
#        [ nan,  nan]])

# %%
AllPartCoords = []
counter = 0
for file in JPGFiles:
    ImageDir = CImagesDir+'/'+file
    print(str(counter)+'/'+ str(len(JPGFiles)), end='\r')
    counter +=1
    AllPartCoords.append(partCoordsOfImage(ImageDir))
# Out:
# 5/9532
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b78d15a938ea> in <module>
#       6     print(str(counter)+'/'+ str(len(JPGFiles)), end='\r')
#       7     counter +=1
# ----> 8     AllPartCoords.append(partCoordsOfImage(ImageDir))
#       9
#      10 from tempfile import TemporaryFile
#
# <ipython-input-6-5ecc73aed0e2> in partCoordsOfImage(input_image)
#      18         #print("Input shape: " + str(input_img.shape))
#      19
# ---> 20         output_blobs = model.predict(input_img)
#      21         #print("Output shape (heatmap): " + str(output_blobs[1].shape))
#      22
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# ...

# %%
np.save("partCoords_new.npy", np.array(AllPartCoords))
